# %%
#Class Task 1
num=int(input("Enter a Number"))
if num%2==0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a Number-44
# The number is even

# %%
#Class Task 2
num_1=int(input('Enter a number:'))
num_2=int(input('Enter a number:'))
if (num_1>num_2):
 print('Frist is greater')
elif(num_1<num_2):
 print('Second is grater')
else:
  print('The numbers are equal')
# Out:
# Enter a number:7
# Enter a number:3
# Frist is greater

# %%
#Class Task 3
num=int(input('Enter a number'))
if num%2==0 or num%5==0 :
 print('It is a multiple 2 or 5')
else:
  print('Not multiple of 2 or 5')
# Out:
# Enter a number5
# It is a multiple 2 or 5

# %%
#Class Task 4
num=int(input('Enter a number'))
if num%2==0 and num%5==0 :
 print('It is a multiple 2 and 5 both')
else:
  print('Not a multiple 2 and 5 both')
# Out:
# Enter a number10
# It is a multiple 2 and 5 both

# %%
#Class Task 5
cgpa = float(input("Enter CGPA: "))
credits_completed = int(input("Enter the number of completed credits: "))
if cgpa < 3.8 and credits_completed < 30:
  print("The student is not eligible for a waiver.")
else:
  if cgpa >=3.80 and cgpa <=3.89:
    waiver_percentage =25
    print("The student is eligible for a waiver of 25 percent")
  if cgpa >=3.90 and cgpa <=3.94:
   waiver_percentage = 50
   print("The student is eligible for a waiver of 50 percent")
  if cgpa >= 3.95 and cgpa <=3.99:
    waiver_percentage = 70
    print("The student is eligible for a waiver of 70 percent")
  elif cgpa == 4.0:
    waiver_percentage = 100
    print("The student is eligible for a waiver of 100 percent")
# Out:
# Enter CGPA: 3.93
# Enter the number of completed credits: 78
# The student is eligible for a waiver of 50 percent

# %%
#Class Task 6
p = 5
q = 6
r = 9
sum = 0
if (p < 12):
 print(r + 2)
else:
 print(r + p)
if (q > 20):
 print(r + 19)
elif (q <= 6):
  print(q + 3)
else:
  print(p + q + r)
if (r > 15):
 print(r)
elif (r == 0):
 print(p + q)
else:
 print(p)
if (sum != 0):
 print(3)
else:
 print(sum + 32)
if (p > 0 and r < 10):
 print(p + r)
else:
 print(p - r)
# Out:
# 11
# 9
# 5
# 32
# 14

# %%
#Class Task 7
var1 = var2 = True
var3 = var4 = var5 = False
result1 = result2 = result3 = True
result4 = result5 = False
var1 = 4 > 3 - 1
var2 = False and var1
var3 = True
var4 = False
var5 = not(var3 or var4)
result1=((var1 or var2) and (8 * 10 > 45))
result2 = (var1 or var2) and (result1 and False)
result3 = (var1 and not result1) or result2
result4 = (var1 or var2) or not((var5 and var1) and False)
result5 = (not var1 and var4) and (result3 or var3)
print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
# Out:
# True
# False
# False
# True
# False

# %%
# Class Evaluation Task 1
hour=int(input('Enter working hour:'))
if hour<40:
  salary=(hour*200)
  print(salary)
elif hour>40:
  salary=(8000+(hour-40)*300)
  print(salary)
if hour>168:
  print('Impossible to work more than 168 hours weekly')
if hour<0:
  print('Hour cannot be negative')
# Out:
# Enter working hour:100
# 26000

# %%
#Class Evaluation Task 2
total_seconds = int(input("Enter the number of seconds:"))
hours = total_seconds // 3600
remaining_seconds = total_seconds % 3600
minutes = remaining_seconds // 60
seconds = remaining_seconds %60
print(("Hours:"+str(hours)))
print(("Minutes:"+str(minutes)))
print(("Seconds:"+str(seconds)))
# Out:
# Enter the number of seconds:10000
# Hours:2
# Minutes:46
# Seconds:40

# %%
#Class Evaluation Task 3
meter=int(input('Enter a number:'))
second=int(input('Enter a number:'))
distance=meter/1000
time=second/3600
velocity=distance/time
print(f'{velocity}km/h')
if velocity<60:
  print("Too slow. It needs more changes.")
elif 60<velocity<90:
 print("Velocity is okay. The car is ready!")
elif velocity>90:
  print("Too fast. Only a few changes should suffice.")
# Out:
# Enter a number:160000
# Enter a number:7200
# 80.0km/h
# Velocity is okay. The car is ready!

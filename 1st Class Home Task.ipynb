# %%
#Home Task 1
print("Hello")
# Out:
# Hello

# %%
print(4+5.5)
# Out:
# 9.5

# %%
x,y=6,10
print(y/y)
print(-5/2)
print(-5//2)
print(y>x)
print(x>y)
print(y==x)
print(y!=x)
print(y>=x)
print(x<=y)
# Out:
# 1.0
# -2.5
# -3
# True
# False
# False
# True
# True
# True

# %%
a=True
b=False
print(a)
print("b")
print(a and b)
print(a or b)
print(a and not b)
print(not a)
# Out:
# True
# b
# False
# True
# True
# False
# 6

# %%
x,y=6,10
y=x
print(x)
print(y)
x-=2
x=x+2
x//=1
print(x)
print(x!=y and a)
print(x*y**2)
print(x+5*4%2-1)
print(x==y*2//2-2**(2-1))
print(x-((x+y%2)*3)//2)
# Out:
# 6
# 6
# 6
# False
# 216
# 5
# False
# -3

# %%
x,y=6,10
print(x-y)
print(x+y)
print(x*y)
print(x**2)
print(y**x)
print(y/3)
print(x%y)
print(y//3)
print(y%x)
print(y%y)
# Out:
# -4
# 16
# 60
# 36
# 1000000
# 3.3333333333333335
# 6
# 3
# 4
# 0

# %%
#Home Task 2
print("Hello"+"Hi")
print("Hello"+" "+"Hi")
print("Hello",end=" ")
print("Hi")
print("Hello")
print("Hi")
print("Yo")
x=5
print(6+int(x))
print("Hi"*3)
# Out:
# HelloHi
# Hello Hi
# Hello Hi
# Hello
# Hi
# Yo
# 11
# HiHiHi

# %%
#Home Task 3
NumberChocolates=int(input("Enter the number of chocolates you have:"))
ChocolatesEachFriend=NumberChocolates//3
RemaingChocolates=NumberChocolates%3
print("Each friend will recive"+" "+str(ChocolatesEachFriend)+" "+"chocolates")
print("The number of remaing chocolates is"+" " +str(RemaingChocolates))
# Out:
# Enter the number of chocolates you have:90
# Each friend will recive 30 chocolates
# The number of remaing chocolates is 0

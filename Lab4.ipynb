# %%
#Class Task 1.1.1
st=input("Enter a string:")
for i in range (-1,-len(st)-1,-1):
 print(st[i],end="")
# Out:
# Enter a string:CSE110
# 011ESC

# %%
#Class Task 1.1.2
st=input("Enter a string:")
print(st[-1:-len(st)-1:-1])
# Out:
# Enter a string:CSE110
# 011ESC

# %%
#Class Task 1.2
st=input("Enter a string:")
p=int(input("Enter a index:"))
print(st[p:-len(st)-1:-1]+st[p:len(st):1])
# Out:
# Enter a string:72418
# Enter a index:4
# 814278

# %%
#Class Task 2.1
st=input("Enter a string:")
for i in range(0,len(st)):
  ascii=ord(st[i])
  print(f"{st[i]}:{ascii}")
# Out:
# Enter a world:quincuncial
# q:113
# u:117
# i:105
# n:110
# c:99
# u:117
# n:110
# c:99
# i:105
# a:97
# l:108

# %%
#Class Task 3
st=input("Enter a string:")
final=''
for i in (st):
 if i=='-':
  print(final)
  final=''
 else:
  final+=i
print(final)
# Out:
# Enter a string:This-is-CSE110
# This
# is
# CSE110

# %%
#Class Task 2.2
st=input("Enter a string:")
for i in range (0,-len(st)):
 if i%!=0:
  print(chr(ord))
# Out:
# Enter a string:This-is CSE110
# 0
# 1
# 1
# E
# S
# C
#
# s
# i
# -
# s
# i
# h
# T

# %%
#Class Task 4
test = ""
i = 1
j = 0
k = 7
while (i< 5):
    k-=1
    j = k
    while (j > 4 ):
        if j % 2 == 0:
            test = "<--"
            test = test + str(i) + '3' + "-->" + str(j // 3)
        else:
            test = "-->"
            test = "-->" + str((i // 3)) + test + str(j)
        print(test)
        j -=1
    i+=2
# Out:
# <--13-->2
# -->0-->5
# -->1-->5

# %%
#Class Evaluation Task 1
st=input("Enter a number:")
count=0
for i in st:
  if i!="0" and i!="1":
    count+=1

if count>0:
    print('Not a Binary Number')
else:
    print('Binary Number')

# %%
#Class Evaluation Task 2
st=input("Enter a phrase:")
count=0
again_count=0
for i in st:
  if 65<=ord(i)<=90 or 97<=ord(i)<=122:
    if i=="a" or i=="e" or i=="i" or i=="o" or i=="u":
     count+=1
    else:
      again_count+=1
if count>0 and again_count>0:
  if count%3==0 and again_count%5==0:
      print("Aaarr! Me Plunder!!")
  else:
      print("Blimey! No Plunder!!")
else:
    print("Blimey! No Plunder!!")
# Out:
# Enter a phrase:Yo-hoo-hoo!
# Blimey! No Plunder!!

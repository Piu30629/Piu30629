# %%
#Home Task 1
num_1=int(input("Enter a Number:"))
num_2=int(input("Enter a Number:"))
if (num_1>num_2):
 result=num_1-num_2
 print(result)
if (num_1<num_2):
  result=num_2-num_1
  print(result)
if (num_1==num_2):
  result=num_1-num_2
  print(result)
# Out:
# Enter a Number:5
# Enter a Number:5
# 0

# %%
#Home Task 2
num=int(input("Enter a number:"))
if (num%2==0 and num%5==0):
  print("Multiple of 2 and 5 both")
elif (num%2==0 or num%5==0):
  print("Multiple of either 2 or 5 but not both")
else:
 print("Not a multiple we want")
# Out:
# Enter a number:6
# Multiple of either 2 or 5 but not both

# %%
#Home Task 3
S=int(input("Enter a number:"))
if(S<100):
  L=3000-(125*(S**2))
  print(L)
if(S>=100):
  L=12000/(4+(S**2)/14900)
  print(L)
# Out:
# Enter a number:3
# 1875

# %%
#Home Task 4
hour=int(input("Enter the hour(0-23):"))
if(0<=hour<=23):
 if (4<=hour<=6):
  print("Breakfast")
 if (12<=hour<=13):
  print("Lunch")
 if(16<=hour<=17):
  print("Snacks")
 if (19<=hour<=20):
  print("Dinner")
 else:
  print("Patience is a virtue")
else:
  print("Wrong time")
# Out:
# Enter the hour(0-23):19
# Dinner

# %%
#Home Task 5
marks=int(input("Enter the marks(0-100):"))
if (0<=marks<=100):
  if(90<=marks<=100):
    print("Gread","A")
  if(80<=marks<=89):
    print("Grade","B")
  if(70<=marks<=79):
    print("Grade","C")
  if(60<=marks<=69):
    print("Grade","D")
  if(50<=marks<=59):
    print("Grade","E")
  if (marks<50):
    print("Grade","F")
# Out:
# Enter the marks(0-100):56
# Grade E

# %%
#Home Task 6
num1 = 10
num2 = -3
num3 = -1
sum = num1 + num2 + num3
if (num3 < 0):
 print(num3 * -2)
else:
 print(sum)
if (num1 < 5):
 print(num1 + 10)
elif (num2 == -3):
 num2 = num1
 print(num2)
else:
 print(num1 + num2 + num3)
if (num1 > 15):
 print(num1)
elif (num2 == 0):
 print(num2 + num3)
else:
 print(num3)
if (sum != 0):
 print(100)
else:
 print(sum + 100)
if (num1 > 0 and num2 < 0):
 print(num1 == num2)
else:
 print("False")
# Out:
# 2
# 10
# -1
# 100
# False

# %%
#Home Task 7
var1 = False
var2 = False
var3 = False
var4 = False
var5 = False
var6 = False
result1 = False
result2 = False
result3 = False
result4 = False
result5 = False
result6 = False
result7 = False
result8 = False
result9 = False
result10 = False
var1 = ((not True) or True) and False
var2 = var1 and False
var3 = True and not False
var4 = False
var5 = True
var6 = var3 and False
print(result1 == (var1 and var2) and (40 % 3) > 45 or (var5 and var6))
print(result2 == (var1 or var2) or (result1 and False))
print(result3 == (var1 and result1) or result2 or var5)
print(result4 == (var1 or var2) or ((var3 and var1) and False))
print(result5 == (var1 and var2) and (result3 or var1))
print(result6 == ((var3 or (not var2)) and (result5)) or True)
print(result7 == (var4 and result1) and ((result1 and False) or True))
print(result8 == ((var1 and result3) and ((not var5) or var6)) and True)
print(result9 == ((result2 and var2) or ((not result7) and var1)) and not False)
print(result10 != (var1 and True))
# Out:
# False
# True
# True
# True
# False
# True
# True
# True
# True
# False

# %%
#Home Task 8
var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = result2 = result3 = result4 = result5 = result6 = False
result7 = result8 = result9 = result10 = False
var1 = (not False or False) and True
var2 = var1 and True
var3 = False and not True
var4 = True
var5 = False
var6 = var3 and True
print(result1 == (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6))
print(result2 == (var1 or var2) or (result1 and False))
print(result3 == (var1 and result1) or result2 or var5)
print(result4 == (var1 or var2) or ((var3 and var1) and False))
print(result5 == (var1 and var2) and (result3 or var1))
print(result6 == ((var3 or not var2) and (result5)) or True)
print(result7 == (var4 and result1) and ((result1 and False) or True))
print(result8 == ((var1 and result3) and (not var5 or var6)) and True)
print(result9 == ((result2 and var2) or (not result7 and var1)) and not False)
print(result10 != (var1 and True))
# Out:
# False
# False
# True
# False
# False
# True
# True
# True
# False
# True
